# %% [markdown]
# # Data Extraction

# %% [markdown]
# ## Spotify

# %%
# Loading necessary libraries

import requests
import base64
import json
import pandas as pd

# %%
# Keys for the Spotify API

client_id = '62f9499b009c49d8b6363890028ce155'
client_secret = '8b1ec143c4d94ea6aa3920b3b8bf2ee6'

# %% [markdown]
# ### Create the artists list:

# %%
# Encode in base64

auth_str = f"{client_id}:{client_secret}"
b64_auth_str = base64.b64encode(auth_str.encode()).decode()

# Request access token
url = "https://accounts.spotify.com/api/token"
headers = {
    "Authorization": f"Basic {b64_auth_str}"
}
data = {
    "grant_type": "client_credentials"
}

response = requests.post(url, headers=headers, data=data)
access_token = response.json()['access_token']

# Headers with access token
headers = {
    "Authorization": f"Bearer {access_token}"
}

#####################################################################################################################################

# Playlist ID for the Top 50 Spain
playlist_id = '37i9dQZEVXbNFJfN1Vw8d9'
url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"

# Make the GET request to fetch the songs in the playlist
response = requests.get(url, headers=headers)
playlist_data = response.json()

# Extract artist names
artist_names = set()  # Use a set to avoid duplicates
for item in playlist_data['items']:
    track = item['track']
    for artist in track['artists']:
        artist_names.add(artist['name'])

#####################################################################################################################################

# Playlist ID for the Top 50 EU
playlist_id = '37i9dQZEVXbLRQDuF5jeBp'
url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"

# Make the GET request to fetch the songs in the playlist
response = requests.get(url, headers=headers)
playlist_data = response.json()

# Extract artist names
for item in playlist_data['items']:
    track = item['track']
    for artist in track['artists']:
        artist_names.add(artist['name'])

#####################################################################################################################################

# Playlist ID for the Top 50 Reino Unido
playlist_id = '37i9dQZEVXbLnolsZ8PSNw'
url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"

# Make the GET request to fetch the songs in the playlist
response = requests.get(url, headers=headers)
playlist_data = response.json()

# Extract artist names
for item in playlist_data['items']:
    track = item['track']
    for artist in track['artists']:
        artist_names.add(artist['name'])

#####################################################################################################################################

# Playlist ID for the Top 50 Argentina
playlist_id = '37i9dQZEVXbMMy2roB9myp'
url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"

# Make the GET request to fetch the songs in the playlist
response = requests.get(url, headers=headers)
playlist_data = response.json()

# Extract artist names
for item in playlist_data['items']:
    track = item['track']
    for artist in track['artists']:
        artist_names.add(artist['name'])

#####################################################################################################################################

# Playlist ID for the Top 50 Argentina
playlist_id = '37i9dQZEVXbMMy2roB9myp'
url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"

# Make the GET request to fetch the songs in the playlist
response = requests.get(url, headers=headers)
playlist_data = response.json()

# Extract artist names
for item in playlist_data['items']:
    track = item['track']
    for artist in track['artists']:
        artist_names.add(artist['name'])

#####################################################################################################################################

# Playlist ID for the Top 50 Francia
playlist_id = '37i9dQZEVXbIPWwFssbupI'
url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"

# Make the GET request to fetch the songs in the playlist
response = requests.get(url, headers=headers)
playlist_data = response.json()

# Extract artist names
for item in playlist_data['items']:
    track = item['track']
    for artist in track['artists']:
        artist_names.add(artist['name'])
        
#####################################################################################################################################

# Playlist ID for the Top 50 Italia
playlist_id = '37i9dQZEVXbIQnj7RRhdSX'
url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"

# Make the GET request to fetch the songs in the playlist
response = requests.get(url, headers=headers)
playlist_data = response.json()

# Extract artist names
for item in playlist_data['items']:
    track = item['track']
    for artist in track['artists']:
        artist_names.add(artist['name'])
        
#####################################################################################################################################

# Playlist ID for the Top 50 Portugal
playlist_id = '37i9dQZEVXbKyJS56d1pgi'
url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks"

# Make the GET request to fetch the songs in the playlist
response = requests.get(url, headers=headers)
playlist_data = response.json()

# Extract artist names
for item in playlist_data['items']:
    track = item['track']
    for artist in track['artists']:
        artist_names.add(artist['name'])
        
#####################################################################################################################################

# Convert set to list and print
artist_names_list = list(artist_names)
print(artist_names)
print(len(artist_names_list))
# Out:
# {'Jay Wheeler', 'Skread', 'DobleP', 'Las 2K', 'Kavinsky', 'ERNEST', 'Ivandro', 'Gracie Abrams', 'Luke Combs', 'Myles Smith', 'La Mano 1.9', 'BL3SS', 'Lazza', 'La T y La M', 'DJ TOPO', 'FloyyMenor', 'Simba La Rue', 'KAROL G', 'Kapo', 'Un Poco de Ruido', 'Angelina Mango', 'Bárbara Bandeira', 'Tony Boy', 'La La Love You', 'Daecolm', 'Frank Ocean', 'Seu Jorge', 'Julinho Ksd', 'Beny Jr', 'GIMS', 'Olly', 'Emma', 'Booba', 'Van Zee', 'KHEA', 'JVLI', 'Lynda', 'Niky Savage', 'Tedua', 'Alessandra Amoroso', 'Chase & Status', 'Artie 5ive', 'Angèle', 'VEN1', 'De La Rose', 'FRANKIEONTHEGUITAR', 'Diegote', "Q' Lokura", 'Dr. Yaro', 'KeBlack', 'Marracash', 'ECKO', 'MC G15', 'Mc Leozin', 'Kidd Keo', 'Dat Boi Dee', 'Teddy Swims', 'Leto', 'LOUKI', 'Abel Pintos', 'Addison Rae', 'Tony Effe', 'Grelo', 'Ghali', 'Neton Vega', 'Prototype', 'Rsko', 'Franglish', 'Kacey Musgraves', 'Rvfv', 'The Cranberries', 'Pinky SD', 'Dani Fernández', 'Dasha', 'Bhavi', 'FT Kings', 'The Weeknd', 'Rose Villain', 'Cristian Di Marco', 'JC Reyes', 'Chardo Chardemio', 'girl in red', 'Morgan Wallen', "Heuss L'enfoiré", 'Uriel Lozano', 'Ninho', 'J Abdiel', 'Dadi', 'La Joaqui', 'Sfera Ebbasta', 'Cosang', 'Milo j', 'Sevdaliza', 'Mizzy Miles', 'Salastkbron', 'Gunna', 'Gusty dj', 'Don Pero', 'iZaak', '*NSYNC', 'Anitta', 'Omar Varela', 'Kali Uchis', 'The La Planta', 'Omar Courtz', 'Mark Ambor', 'TINI', 'Gasparzinho', 'Lola Indigo', 'Bruno Mars', 'Angela Torres', 'Tiakola', 'Phoenix', 'Chayanne', 'Dillaz', 'KayBlack', 'Big One', 'Favé', 'Malachiii', 'Figa Flawas', 'iñigo quintero', 'Tiago PZK', 'Tuti DJ', 'Walls', 'Taiu', 'SDM', 'SYRO', 'Jordan Adetunji', 'Cesare Cremonini', 'Liim’s', 'Teto', 'Los Sufridos', 'Noah Kahan', 'Taylor Swift', 'The Killers', 'Ana Mena', 'Valentino Merlo', 'Pereiraremix', 'Niska', 'Ralphie Choo', 'Sonny Fodera', 'Luchè', 'Morad', 'Stryv', 'Bad Bunny', 'Lomiiel', 'Lil Baby', 'Ghost Killer Track', 'Bryant Myers', 'Ndotz', 'Laura Pausini', 'Sabrina Carpenter', 'Stormzy', 'Matuê', 'BM', 'Melody Records International', 'Sillyelly', 'Dei V', 'PLK', 'Bispo', 'Malandro', 'Keinemusik', 'Bresh', 'Gonzy', 'Tananai', 'Karina', 'Plutonio', 'Quevedo', 'Emanero', 'Myke Towers', 'Los Ángeles Azules', 'Maria Becerra', 'Yan Block', 'Hamza', 'Bouss', 'ANNA', 'Axolotes Mexicanos', 'Lali', 'Gaia', 'Vance Joy', 'AMK', 'ATL Jacob', 'Arcángel', 'Pabllo Vittar', 'Annalisa', 'BigMama', 'Diel Paris', 'Arash', 'Takagi & Ketra', 'Omar Montes', 'Adam Port', 'The Kid LAROI', 'THEODORT', 'Veigh', 'MC Meno K', 'Carbonne', 'Geolier', 'Ayra Starr', 'Trueno', 'Gigi Perez', 'BigXthaPlug', 'The Goo Goo Dolls', 'Paulo Londra', 'HUGEL', 'Marshmello', 'Chappell Roan', 'Richie Campbell', 'Benson Boone', 'Tate McRae', 'YSY A', 'Maisak', 'Ultimo', 'Playboi Carti', 'Wall Hein', 'Ramos.', 'Rvssian', 'Peso Pluma', 'The Marías', 'Plan B', 'Josman', 'Laylow', 'Indi C', 'ROSALÍA', 'Feid', 'Zach Bryan', 'Jimin', 'Emilia', 'Yseult', 'Werenoi', 'Genezio', 'Gazo', 'WIU', 'Elodie', 'Luísa Sonza', 'Nicki Nicole', 'j mena', 'Topic', 'Billie Eilish', 'Linkin Park', 'Luck Ra', 'Bad Gyal', 'Wet Bed Gang', 'Lady Gaga', 'KEVIN ROLDAN', 'Kid Yugi', 'Hozier', 'Travis Scott', 'Slow J', 'Guy2Bezbar', 'Tommy Richman', 'Manuel Turizo', 'Crowded House', 'DYSTINCT', 'PEDRO SAMPAIO', 'Shaboozey', 'Lacrim', 'Ke Personajes', 'Kendrick Lamar', 'Orso', 'No Te Va Gustar', 'Shiva', 'Coldplay', 'Yandel', 'Jazzy', 'Charli xcx', 'Ntò', 'Cris Mj', 'Rauw Alejandro', 'Rels B', 'Los Turros', 'Guè', 'bbyclose', 'CamrinWatsin', 'SAIKO', 'Ryflo', 'D.O.D', 'Darell', 'Sal Da Vinci', 'Mahmood', 'Vacra', 'Tyler, The Creator', 'Shakira', 'Oskoow', 'Yorssy', 'GBoss', 'Bluay', 'Pinguini Tattici Nucleari', 'The Neighbourhood', 'Fedez', 'AMUSIK', 'Haze', 'Michael Marcagi', 'Post Malone'}
# 293

# %% [markdown]
# Save artists lists into a .txt file:

# %%
artist_names_file = '/Users/evamartin/Desktop/MDS/curs1/ADSDB/artist_names_list.txt'

with open(artist_names_file, 'w') as file:
    for artist in artist_names_list:
        file.write(artist + '\n')

print("Artist names saved to artist_names_list.txt")
# Out:
# Artist names saved to artist_names_list.txt

# %% [markdown]
# Build the arists names list from the .txt file:

# %%
with open(artist_names_file, 'r') as file:
    artist_names = [line.strip() for line in file]

# %%
artist_names
# Out:
# ['Jay Wheeler',
#  'Skread',
#  'DobleP',
#  'Las 2K',
#  'Kavinsky',
#  'ERNEST',
#  'Ivandro',
#  'Gracie Abrams',
#  'Luke Combs',
#  'Myles Smith',
#  'La Mano 1.9',
#  'BL3SS',
#  'Lazza',
#  'La T y La M',
#  'DJ TOPO',
#  'FloyyMenor',
#  'Simba La Rue',
#  'KAROL G',
#  'Kapo',
#  'Un Poco de Ruido',
#  'Angelina Mango',
#  'Bárbara Bandeira',
#  'Tony Boy',
#  'La La Love You',
#  'Daecolm',
#  'Frank Ocean',
#  'Seu Jorge',
#  'Julinho Ksd',
#  'Beny Jr',
#  'GIMS',
#  'Olly',
#  'Emma',
#  'Booba',
#  'Van Zee',
#  'KHEA',
#  'JVLI',
#  'Lynda',
#  'Niky Savage',
#  'Tedua',
#  'Alessandra Amoroso',
#  'Chase & Status',
#  'Artie 5ive',
#  'Angèle',
#  'VEN1',
#  'De La Rose',
#  'FRANKIEONTHEGUITAR',
#  'Diegote',
#  "Q' Lokura",
#  'Dr. Yaro',
#  'KeBlack',
#  'Marracash',
#  'ECKO',
#  'MC G15',
#  'Mc Leozin',
#  'Kidd Keo',
#  'Dat Boi Dee',
#  'Teddy Swims',
#  'Leto',
#  'LOUKI',
#  'Abel Pintos',
#  'Addison Rae',
#  'Tony Effe',
#  'Grelo',
#  'Ghali',
#  'Neton Vega',
#  'Prototype',
#  'Rsko',
#  'Franglish',
#  'Kacey Musgraves',
#  'Rvfv',
#  'The Cranberries',
#  'Pinky SD',
#  'Dani Fernández',
#  'Dasha',
#  'Bhavi',
#  'FT Kings',
#  'The Weeknd',
#  'Rose Villain',
#  'Cristian Di Marco',
#  'JC Reyes',
#  'Chardo Chardemio',
#  'girl in red',
#  'Morgan Wallen',
#  "Heuss L'enfoiré",
#  'Uriel Lozano',
#  'Ninho',
#  'J Abdiel',
#  'Dadi',
#  'La Joaqui',
#  'Sfera Ebbasta',
#  'Cosang',
#  'Milo j',
#  'Sevdaliza',
#  'Mizzy Miles',
#  'Salastkbron',
#  'Gunna',
#  'Gusty dj',
#  'Don Pero',
#  'iZaak',
#  '*NSYNC',
#  'Anitta',
#  'Omar Varela',
#  'Kali Uchis',
#  'The La Planta',
#  'Omar Courtz',
#  'Mark Ambor',
#  'TINI',
#  'Gasparzinho',
#  'Lola Indigo',
#  'Bruno Mars',
#  'Angela Torres',
#  'Tiakola',
#  'Phoenix',
#  'Chayanne',
#  'Dillaz',
#  'KayBlack',
#  'Big One',
#  'Favé',
#  'Malachiii',
#  'Figa Flawas',
#  'iñigo quintero',
#  'Tiago PZK',
#  'Tuti DJ',
#  'Walls',
#  'Taiu',
#  'SDM',
#  'SYRO',
#  'Jordan Adetunji',
#  'Cesare Cremonini',
#  'Liim’s',
#  'Teto',
#  'Los Sufridos',
#  'Noah Kahan',
#  'Taylor Swift',
#  'The Killers',
#  'Ana Mena',
#  'Valentino Merlo',
#  'Pereiraremix',
#  'Niska',
#  'Ralphie Choo',
#  'Sonny Fodera',
#  'Luchè',
#  'Morad',
#  'Stryv',
#  'Bad Bunny',
#  'Lomiiel',
#  'Lil Baby',
#  'Ghost Killer Track',
#  'Bryant Myers',
#  'Ndotz',
#  'Laura Pausini',
#  'Sabrina Carpenter',
#  'Stormzy',
#  'Matuê',
#  'BM',
#  'Melody Records International',
#  'Sillyelly',
#  'Dei V',
#  'PLK',
#  'Bispo',
#  'Malandro',
#  'Keinemusik',
#  'Bresh',
#  'Gonzy',
#  'Tananai',
#  'Karina',
#  'Plutonio',
#  'Quevedo',
#  'Emanero',
#  'Myke Towers',
#  'Los Ángeles Azules',
#  'Maria Becerra',
#  'Yan Block',
#  'Hamza',
#  'Bouss',
#  'ANNA',
#  'Axolotes Mexicanos',
#  'Lali',
#  'Gaia',
#  'Vance Joy',
#  'AMK',
#  'ATL Jacob',
#  'Arcángel',
#  'Pabllo Vittar',
#  'Annalisa',
#  'BigMama',
#  'Diel Paris',
#  'Arash',
#  'Takagi & Ketra',
#  'Omar Montes',
#  'Adam Port',
#  'The Kid LAROI',
#  'THEODORT',
#  'Veigh',
#  'MC Meno K',
#  'Carbonne',
#  'Geolier',
#  'Ayra Starr',
#  'Trueno',
#  'Gigi Perez',
#  'BigXthaPlug',
#  'The Goo Goo Dolls',
#  'Paulo Londra',
#  'HUGEL',
#  'Marshmello',
#  'Chappell Roan',
#  'Richie Campbell',
#  'Benson Boone',
#  'Tate McRae',
#  'YSY A',
#  'Maisak',
#  'Ultimo',
#  'Playboi Carti',
#  'Wall Hein',
#  'Ramos.',
#  'Rvssian',
#  'Peso Pluma',
#  'The Marías',
#  'Plan B',
#  'Josman',
#  'Laylow',
#  'Indi C',
#  'ROSALÍA',
#  'Feid',
#  'Zach Bryan',
#  'Jimin',
#  'Emilia',
#  'Yseult',
#  'Werenoi',
#  'Genezio',
#  'Gazo',
#  'WIU',
#  'Elodie',
#  'Luísa Sonza',
#  'Nicki Nicole',
#  'j mena',
#  'Topic',
#  'Billie Eilish',
#  'Linkin Park',
#  'Luck Ra',
#  'Bad Gyal',
#  'Wet Bed Gang',
#  'Lady Gaga',
#  'KEVIN ROLDAN',
#  'Kid Yugi',
#  'Hozier',
#  'Travis Scott',
#  'Slow J',
#  'Guy2Bezbar',
#  'Tommy Richman',
#  'Manuel Turizo',
#  'Crowded House',
#  'DYSTINCT',
#  'PEDRO SAMPAIO',
#  'Shaboozey',
#  'Lacrim',
#  'Ke Personajes',
#  'Kendrick Lamar',
#  'Orso',
#  'No Te Va Gustar',
#  'Shiva',
#  'Coldplay',
#  'Yandel',
#  'Jazzy',
#  'Charli xcx',
#  'Ntò',
#  'Cris Mj',
#  'Rauw Alejandro',
#  'Rels B',
#  'Los Turros',
#  'Guè',
#  'bbyclose',
#  'CamrinWatsin',
#  'SAIKO',
#  'Ryflo',
#  'D.O.D',
#  'Darell',
#  'Sal Da Vinci',
#  'Mahmood',
#  'Vacra',
#  'Tyler, The Creator',
#  'Shakira',
#  'Oskoow',
#  'Yorssy',
#  'GBoss',
#  'Bluay',
#  'Pinguini Tattici Nucleari',
#  'The Neighbourhood',
#  'Fedez',
#  'AMUSIK',
#  'Haze',
#  'Michael Marcagi',
#  'Post Malone']

# %% [markdown]
# ### 1) Retrieve artists information from Spotify API (save it in a JSON file)

# %%
artist_info = []

# Loop through the list of artist names and retrieve their info from Spotify
for artist_name in artist_names:
    search_url = f"https://api.spotify.com/v1/search?q={artist_name}&type=artist"
    response = requests.get(search_url, headers=headers)
    
    # Check if the request was successful
    if response.status_code == 200:
        result = response.json()
        
        # Check if any artist data was returned
        if 'artists' in result and len(result['artists']['items']) > 0:
            # Append the artist info to the list
            artist_info.append(result['artists']['items'][0])

# Save the results to a JSON file
with open('spotify_data.json', 'w') as json_file:
    json.dump(artist_info, json_file, indent=4)

# %% [markdown]
# ### 2) Load artists data from JSON file

# %%
# Load the artist data from the JSON file
with open('spotify_data.json', 'r') as json_file:
    artist_data = json.load(json_file)

# %% [markdown]
# ### 3) Build CSV with the data from JSON file

# %%
# Prepare a list of dictionaries with the extracted artist info
artist_kpis = []
for artist in artist_data:
    artist_info = {
        'name': artist['name'],
        'genres': ', '.join(artist.get('genres', [])),  # Join genres as a comma-separated string
        'followers': artist['followers']['total'],
        'popularity': artist['popularity']
    }
    artist_kpis.append(artist_info)

# Create a pandas DataFrame from the list
df = pd.DataFrame(artist_kpis)

# %%
df
# Out:
#                 name                                 genres  followers  \
# 0        Jay Wheeler  reggaeton, trap latino, urbano latino    4351960
# 1             Skread                          rap conscient      18733
# 2             DobleP                                            187012
# 3             Las 2K                                              2602
# 4           Kavinsky                           filter house     932454
# ..               ...                                    ...        ...
# 288            Fedez         italian adult pop, italian pop    2044531
# 289           AMUSIK                        trap brasileiro      20616
# 290      Haze glitch                                             10690
# 291  Michael Marcagi                                            189623
# 292      Post Malone         dfw rap, melodic rap, pop, rap   45465593
#
#      popularity
# 0            80
# 1            52
# 2            69
# 3            58
# 4            66
# ..          ...
# 288          69
# 289          68
# 290          24
# 291          74
# 292          92
#
# [293 rows x 4 columns]

# %%
df.to_csv('spotify_data.csv', index=False)
